# %% [markdown]
# <a href="https://colab.research.google.com/github/tobbyyan-barker/machinelearning111/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Out:
# --2025-07-19 09:32:15--  https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170498071 (163M) [application/x-gzip]
# Saving to: ‘cifar-10-python.tar.gz’
#
# cifar-10-python.tar 100%[===================>] 162.60M  46.0MB/s    in 3.9s
#
# 2025-07-19 09:32:19 (41.4 MB/s) - ‘cifar-10-python.tar.gz’ saved [170498071/170498071]

# %%
# !tar -zxvf cifar-10-python.tar.gz
# Out:
# cifar-10-batches-py/
# cifar-10-batches-py/data_batch_4
# cifar-10-batches-py/readme.html
# cifar-10-batches-py/test_batch
# cifar-10-batches-py/data_batch_3
# cifar-10-batches-py/batches.meta
# cifar-10-batches-py/data_batch_2
# cifar-10-batches-py/data_batch_5
# cifar-10-batches-py/data_batch_1

# %%
import pickle

def unpickle(file):
    with open(file, 'rb') as fo:
        data_dict = pickle.load(fo, encoding='bytes')
    return data_dict

# 1. 定义我们要读取的文件的“地址”（路径）
# 因为 data_batch_1 文件在 cifar-10-batches-py 文件夹里，所以路径是这样的
file_path = 'cifar-10-batches-py/data_batch_1'

# 2. 调用函数，把地址告诉它，它会返回一个字典
batch_1_data = unpickle(file_path)

# 3. 检查一下我们是否成功拿到了数据
print("成功读取！数据类型是:", type(batch_1_data))
print("字典里包含的键:", batch_1_data.keys())

images = batch_1_data[b'data']
print(images)
labels = batch_1_data[b'labels']
print(labels)
print("第一批数据的图片数量:", len(labels))
# Out:
# 成功读取！数据类型是: <class 'dict'>
# 字典里包含的键: dict_keys([b'batch_label', b'labels', b'data', b'filenames'])
# [[ 59  43  50 ... 140  84  72]
#  [154 126 105 ... 139 142 144]
#  [255 253 253 ...  83  83  84]
#  ...
#  [ 71  60  74 ...  68  69  68]
#  [250 254 211 ... 215 255 254]
#  [ 62  61  60 ... 130 130 131]]
# [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6, 4, 3, 6, 6, 2, 6, 3, 5, 4, 0, 0, 9, 1, 3, 4, 0, 3, 7, 3, 3, 5, 2, 2, 7, 1, 1, 1, 2, 2, 0, 9, 5, 7, 9, 2, 2, 5, 2, 4, 3, 1, 1, 8, 2, 1, 1, 4, 9, 7, 8, 5, 9, 6, 7, 3, 1, 9, 0, 3, 1, 3, 5, 4, 5, 7, 7, 4, 7, 9, 4, 2, 3, 8, 0, 1, 6, 1, 1, 4, 1, 8, 3, 9, 6, 6, 1, 8, 5, 2, 9, 9, 8, 1, 7, 7, 0, 0, 6, 9, 1, 2, 2, 9, 2, 6, 6, 1, 9, 5, 0, 4, 7, 6, 7, 1, 8, 1, 1, 2, 8, 1, 3, 3, 6, 2, 4, 9, 9, 5, 4, 3, 6, 7, 4, 6, 8, 5, 5, 4, 3, 1, 8, 4, 7, 6, 0, 9, 5, 1, 3, 8, 2, 7, 5, 3, 4, 1, 5, 7, 0, 4, 7, 5, 5, 1, 0, 9, 6, 9, 0, 8, 7, 8, 8, 2, 5, 2, 3, 5, 0, 6, 1, 9, 3, 6, 9, 1, 3, 9, 6, 6, 7, 1, 0, 9, 5, 8, 5, 2, 9, 0, 8, 8, 0, 6, 9, 1, 1, 6, 3, 7, 6, 6, 0, 6, 6, 1, 7, 1, 5, 8, 3, 6, 6, 8, 6, 8, 4, 6, 6, 1, 3, 8, 3, 4, 1, 7, 1, 3, 8, 5, 1, 1, 4, 0, 9, 3, 7, 4, 9, 9, 2, 4, 9, 9, 1, 0, 5, 9, 0, 8, 2, 1, 2, 0, 5, 6, 3, 2, 7, 8, 8, 6, 0, 7, 9, 4, 5, 6, 4, 2, 1, 1, 2, 1, 5, 9, 9, 0, 8, 4, 1, 1, 6, 3, 3, 9, 0, 7, 9, 7, 7, 9, 1, 5, 1, 6, 6, 8, 7, 1, 3, 0, 3, 3, 2, 4, 5, 7, 5, 9, 0, 3, 4, 0, 4, 4, 6, 0, 0, 6, 6, 0, 8, 1, 6, 2, 9, 2, 5, 9, 6, 7, 4, 1, 8, 7, 3, 6, 9, 3, 0, 4, 0, 5, 1, 0, 3, 4, 8, 5, 4, 7, 2, 3, 9, 7, 6, 7, 1, 4, 7, 0, 1, 7, 3, 1, 8, 4, 4, 2, 0, 2, 2, 0, 0, 9, 0, 9, 6, 8, 2, 7, 7, 4, 0, 3, 0, 8, 9, 4, 2, 7, 2, 5, 2, 5, 1, 9, 4, 8, 5, 1, 7, 4, 4, 0, 6, 9, 0, 7, 8, 8, 9, 9, 3, 3, 4, 0, 4, 5, 6, 6, 0, 1, 0, 8, 0, 4, 8, 8, 1, 5, 2, 6, 8, 1, 0, 0, 7, 7, 5, 9, 6, 2, 8, 3, 4, 7, 3, 9, 0, 1, 2, 4, 8, 1, 8, 6, 4, 4, 5, 7, 1, 3, 9, 8, 0, 1, 7, 5, 8, 2, 8, 0, 4, 1, 8, 9, 8, 2, 9, 9, 2, 7, 5, 7, 3, 8, 8, 4, 4, 2, 7, 1, 6, 4, 0, 4, 6, 9, 7, 6, 2, 5, 5, 1, 7, 2, 2, 2, 9, 5, 4, 2, 7, 8, 1, 3, 4, 3, 7, 6, 9, 8, 0, 6, 0, 2, 2, 2, 1, 8, 4, 0, 1, 8, 8, 1, 5, 7, 6, 4, 5, 8, 7, 1, 9, 1, 9, 8, 4, 7, 3, 8, 8, 2, 6, 6, 7, 1, 6, 8, 1, 9, 7, 8, 3, 0, 1, 0, 8, 8, 3, 0, 0, 1, 5, 0, 8, 8, 7, 9, 9, 0, 9, 4, 1, 3, 6, 6, 4, 4, 7, 5, 6, 0, 8, 0, 3, 2, 8, 4, 6, 9, 9, 7, 0, 3, 3, 6, 7, 4, 9, 1, 6, 2, 7, 2, 2, 0, 6, 7, 5, 7, 6, 8, 9, 0, 9, 4, 4, 7, 0, 9, 4, 9, 6, 9, 4, 5, 7, 9, 2, 4, 5, 1, 4, 3, 9, 6, 5, 6, 9, 3, 3, 5, 0
, 0, 4, 9, 0, 7, 0, 9, 7, 2, 6, 4, 6, 9, 5, 4, 7, 0, 6, 8, 8, 9, 9, 9, 0, 9, 8, 6, 4, 8, 1, 9, 1, 0, 5, 8, 6, 9, 6, 0, 8, 1, 3, 9, 4, 8, 4, 3, 2, 6, 0, 8, 9, 9, 4, 3, 0, 2, 4, 4, 0, 3, 5, 7, 5, 7, 7, 9, 0, 9, 5, 3, 8, 2, 4, 2, 3, 1, 2, 8, 9, 2, 8, 1, 4, 2, 0, 4, 5, 4, 8, 1, 7, 4, 1, 1, 0, 2, 7, 7, 4, 4, 4, 4, 8, 4, 3, 6, 6, 0, 1, 3, 9, 8, 4, 8, 9, 6, 2, 0, 5, 5, 9,  ...
# 第一批数据的图片数量: 10000

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#近邻算法代码---核心: 就是找到和当前图像距离最小的点 训练死记硬背 预测勤能补拙

#导入相应的库:
import numpy as np

#加载训练图片，训练标签，预测图片，预测标签
Xtr,Ytr,Xtl,Ytl = load_CIFAR10("")

#把图像数据拉伸成行向量: 电脑没办法直接看懂彩色图片
Xtr_rows = Xtr.reshape(Xtr.shape[0],32*32*3)
Xtl_rows = Xtl.reshape(Xtl.shape[0],32*32*3)

#自定义分类器: 分类器包含构造函数， 训练函数 和 预测函数 --- 有这么多函数:写自定义类
class Nearest_Neighbourhood(object):
  def __init__(self):
    pass

  def training(self,x,y):
    self.Xtr_rows = x
    self.Ytr = y

  def predicting(self,X):
    num_length = X.shape[0]
    Y_pred = np.zeros(num_length,dtype = self.Ytr.dtype)
    for i in range(num_length):
      distance = np.sum(abs(self.Xtr_rows - X[i,:]), axis = 1)
      min_index = np.argmin(distance)
      Y_pred[i] = self.Ytr[min_index]

    return Y_pred

#实例化nn对象，调用类里面的训练和预测函数来完成:
nn=Nearest_Neighbourhood()
nn.training(Xtr_rows,Ytr)
Y_predict = nn.predicting(Xtl_rows)
print(f"accurancy is {np.mean(Y_predict==Ytl)}")

# %%
# 导入相应的库
import numpy as np
import pickle
import os

# ================================================================
# 1. 实现 load_CIFAR10 函数
# ================================================================
def unpickle(file):
    """一个辅助函数，用来读取pickle格式的文件"""
    with open(file, 'rb') as fo:
        data_dict = pickle.load(fo, encoding='bytes')
    return data_dict

def load_CIFAR10(ROOT):
    """
    加载并整合CIFAR-10数据集
    ROOT: 存放数据集文件夹cifar-10-batches-py的根目录
    """
    xs = []
    ys = []
    # 循环加载5个训练批次文件
    for b in range(1, 6):
        f = os.path.join(ROOT, 'data_batch_%d' % (b,))
        X = unpickle(f)
        xs.append(X[b'data'])
        ys.append(X[b'labels'])

    # 将5个批次的数据整合到一个大的numpy数组中
    Xtr = np.concatenate(xs)
    Ytr = np.concatenate(ys)
    del xs, ys

    # 加载测试文件
    Xte = unpickle(os.path.join(ROOT, 'test_batch'))
    Yte = np.array(Xte[b'labels'])
    Xte = Xte[b'data']

    return Xtr, Ytr, Xte, Yte

# ================================================================
# 2. 自定义分类器 (修正了内部错误，并使用了更通用的方法名 train/predict)
# ================================================================
class NearestNeighbor(object):
    def __init__(self):
        pass

    def train(self, x, y):
        """ 训练阶段：直接记住所有数据 """
        self.X_train = x
        self.y_train = y

    def predict(self, X_test):
        """ 预测阶段：为每一张测试图片寻找最近邻 """
        num_test = X_test.shape[0]
        y_pred = np.zeros(num_test, dtype=self.y_train.dtype)

        for i in range(num_test):
            # 找到和第i张测试图片距离最近的训练图片
            # 使用了正确的内部变量 self.X_train 和传入参数 X_test[i,:]
            distances = np.sum(np.abs(self.X_train - X_test[i,:]), axis=1)
            min_index = np.argmin(distances) # 找到最小距离的索引
            y_pred[i] = self.y_train[min_index] # 预测标签

            # 加上一个打印输出，方便我们看到进度
            if (i + 1) % 100 == 0:
                print(f"Predicted {i+1}/{num_test} images")

        return y_pred

# ================================================================
# 3. 主程序流程
# ================================================================
# **重要**: 请将这里的路径改成你存放 cifar-10-batches-py 文件夹的路径
# 在Colab中，如果解压在主目录，路径就是 'cifar-10-batches-py'
cifar10_dir = 'cifar-10-batches-py'

# 加载数据
X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

# 打印数据形状，确认加载正确
print('Training data shape: ', X_train.shape)
print('Training labels shape: ', y_train.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)

# 把图像数据拉伸成行向量 (这一步其实在load_CIFAR10里已经包含了，数据本身就是3072维的)
# 如果加载的是原始图片，这一步是必须的。但CIFAR-10的数据已经是拉伸好的了。

# 为了代码清晰，我们直接用加载好的数据，不再reshape
X_train_rows = X_train
X_test_rows = X_test


# 实例化nn对象，调用类里面的训练和预测函数来完成
nn = NearestNeighbor()
nn.train(X_train_rows, y_train)

# 调用正确的预测函数
y_predict = nn.predict(X_test_rows)

# 打印准确率 (修正了拼写错误)
accuracy = np.mean(y_predict == y_test)
print(f"Accuracy: {accuracy}")
# Out:
# Training data shape:  (50000, 3072)
# Training labels shape:  (50000,)
# Test data shape:  (10000, 3072)
# Test labels shape:  (10000,)
# Predicted 100/10000 images
# Predicted 200/10000 images
# Predicted 300/10000 images
# Predicted 400/10000 images
# Predicted 500/10000 images
# Predicted 600/10000 images
# Predicted 700/10000 images
# Predicted 800/10000 images
# Predicted 900/10000 images
# Predicted 1000/10000 images
# Predicted 1100/10000 images
# Predicted 1200/10000 images
# Predicted 1300/10000 images
# Predicted 1400/10000 images
# Predicted 1500/10000 images
# Predicted 1600/10000 images
# Predicted 1700/10000 images
# Predicted 1800/10000 images
# Predicted 1900/10000 images
# Predicted 2000/10000 images
# Predicted 2100/10000 images
# Predicted 2200/10000 images
# Predicted 2300/10000 images
# Predicted 2400/10000 images
# Predicted 2500/10000 images
# Predicted 2600/10000 images
# Predicted 2700/10000 images
# Predicted 2800/10000 images
# Predicted 2900/10000 images
# Predicted 3000/10000 images
# Predicted 3100/10000 images
# Predicted 3200/10000 images
# Predicted 3300/10000 images
# Predicted 3400/10000 images
# Predicted 3500/10000 images
# Predicted 3600/10000 images
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-9-1156602525.py in <cell line: 0>()
#      98
#      99 # 调用正确的预测函数
# --> 100 y_predict = nn.predict(X_test_rows)
#     101
#     102 # 打印准确率 (修正了拼写错误)
#
# /tmp/ipython-input-9-1156602525.py in predict(self, X_test)
#      59             # 找到和第i张测试图片距离最近的训练图片
#      60             # 使用了正确的内部变量 self.X_train 和传入参数 X_test[i,:]
# ---> 61             distances = np.sum(np.abs(self.X_train - X_test[i,:]), axis=1)
#      62             min_index = np.argmin(distances) # 找到最小距离的索引
#      63             y_pred[i] = self.y_train[min_index] # 预测标签
#
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
#    2387         return res
#    2388
# -> 2389     return _wrapreduction(
#    2390         a, np.add, 'sum', axis, dtype, out,
#    2391         keepdims=keepdims, initial=initial, where=where
#
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# KeyboardInterrupt:
